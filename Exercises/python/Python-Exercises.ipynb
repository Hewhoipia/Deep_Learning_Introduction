# %% [markdown]
# #1- Data type and variables

# %% [markdown]
# ##1.1- Samples

# %%
x = 10
print("x = {}".format(x))
print("Type of x: {}".format(str(type(x))))
print("x is an instance of int: {}".format(isinstance(x, int)))
print("x is an instance of float: {}".format(isinstance(x, float)))
print("x is an instance of float: {}".format(isinstance(x, complex)))
# Out:
# x = 10
# Type of x: <class 'int'>
# x is an instance of int: True
# x is an instance of float: False
# x is an instance of float: False

# %% [markdown]
# ##1.2- Exercises

# %% [markdown]
# ###1.2.1 Number

# %%
"""
Fill your code to this cell to show the output as the cell followed
"""
#YOUR CODE IS HERE
x = 10.5
print("x = {}".format(x))
print("Type of x: {}".format(str(type(x))))
print("x is an instance of int: {}".format(isinstance(x, int)))
print("x is an instance of float: {}".format(isinstance(x, float)))
print("x is an instance of float: {}".format(isinstance(x, complex)))
# Out:
# x = 10.5
# Type of x: <class 'float'>
# x is an instance of int: False
# x is an instance of float: True
# x is an instance of float: False

# %%
"""
Fill your code to this cell to show the output as the cell followed
"""
#YOUR CODE IS HERE
x = 1.5 + 2j
print("x = {}".format(x))
print("Type of x: {}".format(str(type(x))))
print("x is an instance of int: {}".format(isinstance(x, int)))
print("x is an instance of float: {}".format(isinstance(x, float)))
print("x is an instance of float: {}".format(isinstance(x, complex)))
# Out:
# x = (1.5+2j)
# Type of x: <class 'complex'>
# x is an instance of int: False
# x is an instance of float: False
# x is an instance of float: True

# %%
"""
Fill your code to this cell to show the output as the cell followed
"""
#YOUR CODE IS HERE
x = 1.5 + 2j
print("x = {}".format(x))
print("Type of x: {}".format(str(type(x))))
print("x is an instance of (int, float, complex): {}".format(isinstance(x, (int, float, complex))))
# Out:
# x = (1.5+2j)
# Type of x: <class 'complex'>
# x is an instance of (int, float, complex): True

# %% [markdown]
# ###1.2.2 List

# %%
"""
Fill your code to this cell to show the output as the cell followed
"""
#YOUR CODE IS HERE
x = [20, 3, 10, 15, 60]
print("x = {}".format(x))
print("Type of x: {}".format(str(type(x))))
print("x is an instance of int: {}".format(isinstance(x, (int, float, complex))))
print("x is an instance of list: {}".format(isinstance(x, list)))
print("x is an instance of tuple: {}".format(isinstance(x, tuple)))
print("x is an instance of set: {}".format(isinstance(x, set)))
print("x is an instance of dict: {}".format(isinstance(x, dict)))
# Out:
# x = [20, 3, 10, 15, 60]
# Type of x: <class 'list'>
# x is an instance of int: False
# x is an instance of list: True
# x is an instance of tuple: False
# x is an instance of set: False
# x is an instance of dict: False

# %% [markdown]
# ###1.2.3 Tuple

# %%
"""
Fill your code to this cell to show the output as the cell followed
"""
#YOUR CODE IS HERE
x = (20, 3, 10, 15, 60)
print("x = {}".format(x))
print("Type of x: {}".format(str(type(x))))
print("x is an instance of int: {}".format(isinstance(x, (int, float, complex))))
print("x is an instance of list: {}".format(isinstance(x, list)))
print("x is an instance of tuple: {}".format(isinstance(x, tuple)))
print("x is an instance of set: {}".format(isinstance(x, set)))
print("x is an instance of dict: {}".format(isinstance(x, dict)))
# Out:
# x = (20, 3, 10, 15, 60)
# Type of x: <class 'tuple'>
# x is an instance of int: False
# x is an instance of list: False
# x is an instance of tuple: True
# x is an instance of set: False
# x is an instance of dict: False

# %% [markdown]
# ###1.2.4 Set

# %%
"""
Fill your code to this cell to show the output as the cell followed
"""
#YOUR CODE IS HERE
x = {20, 3, 10, 15, 60}
print("x = {}".format(x))
print("Type of x: {}".format(str(type(x))))
print("x is an instance of int: {}".format(isinstance(x, (int, float, complex))))
print("x is an instance of list: {}".format(isinstance(x, list)))
print("x is an instance of tuple: {}".format(isinstance(x, tuple)))
print("x is an instance of set: {}".format(isinstance(x, set)))
print("x is an instance of dict: {}".format(isinstance(x, dict)))
# Out:
# x = {3, 20, 10, 60, 15}
# Type of x: <class 'set'>
# x is an instance of int: False
# x is an instance of list: False
# x is an instance of tuple: False
# x is an instance of set: True
# x is an instance of dict: False

# %% [markdown]
# ###1.2.5 Dictionary

# %%
"""
Fill your code to this cell to show the output as the cell followed
"""
#YOUR CODE IS HERE

keys = list("ABCDE")
values = [20, 3, 10, 15, 60]
x = dict(zip(keys, values))
print("x = {}".format(x))
print("Type of x: {}".format(str(type(x))))
print("x is an instance of int: {}".format(isinstance(x, (int, float, complex))))
print("x is an instance of list: {}".format(isinstance(x, list)))
print("x is an instance of tuple: {}".format(isinstance(x, tuple)))
print("x is an instance of set: {}".format(isinstance(x, set)))
print("x is an instance of dict: {}".format(isinstance(x, dict)))
# Out:
# x = {'A': 20, 'B': 3, 'C': 10, 'D': 15, 'E': 60}
# Type of x: <class 'dict'>
# x is an instance of int: False
# x is an instance of list: False
# x is an instance of tuple: False
# x is an instance of set: False
# x is an instance of dict: True

# %%
"""
In preceeding cell, x is a dictionary
Fill your code show the list of keys stored in x
"""
#YOUR CODE IS HERE
list(x.keys())
# Out:
# dict_keys(['A', 'B', 'C', 'D', 'E'])

# %%
"""
In preceeding cell, x is a dictionary
Fill your code show the list of values stored in x
"""
#YOUR CODE IS HERE
list(x.values())
# Out:
# [20, 3, 10, 15, 60]

# %%
"""
In preceeding cell, x is a dictionary
Fill your code show the list of items (key, value) stored in x
"""
#YOUR CODE IS HERE
list(x.items())
# Out:
# [('A', 20), ('B', 3), ('C', 10), ('D', 15), ('E', 60)]

# %% [markdown]
# * Question:
#
# Type the following code to the cell followed and answer:
# what is the data type of variable y and what is its value?
#
# ```
# y = dict(list(x.items()))
# ```

# %%
# YOUR CODE IS HERE?
y = dict(list(x.items()))
print("Type of y: {}".format(str(type(y))))
list(y.values())
# Out:
# Type of y: <class 'dict'>
# [20, 3, 10, 15, 60]

# %%
values
# Out:
# [20, 3, 10, 15, 60]

# %%
values = "dog, cat, chicken, duck, horse"
values = values.split(",")
values = [v.strip().title() for v in values]

keys = list(range(len(values)))
LK = dict(zip(keys, values))
LK
# Out:
# {0: 'Dog', 1: 'Cat', 2: 'Chicken', 3: 'Duck', 4: 'Horse'}

# %%
prediction = [4, 2, 2, 1, 0, 3, 2, 1]
output = [LK[idx] for idx in prediction]
output
# Out:
# ['Horse', 'Chicken', 'Chicken', 'Cat', 'Dog', 'Duck', 'Chicken', 'Cat']

# %%
str2idx = dict(zip(values, keys))
labels = ['Horse', 'Chicken', 'Chicken', 'Cat', 'Dog', 'Duck', 'Chicken', 'Cat']
idxlabels = [str2idx[s] for s in labels]
idxlabels
# Out:
# [4, 2, 2, 1, 0, 3, 2, 1]

# %% [markdown]
# #### Samples

# %%
import glob
import os
files = glob.glob("./sample_data/*.csv")
files
# Out:
# ['./sample_data/california_housing_train.csv',
#  './sample_data/mnist_test.csv',
#  './sample_data/california_housing_test.csv',
#  './sample_data/mnist_train_small.csv']

# %%
import glob
import os
filesize = os.path.getsize('./sample_data/mnist_test.csv')
filesize # in bytes
# Out:
# 18289443

# %%
import glob
import os

"""
Fill your code to this cell to:
1/ create a dictionary named 'frame' to map from file's name to file's size
2/ show it to have to the output as in the following output cell (see the output)
"""

files = glob.glob("./sample_data/*.csv")
sizes = [os.path.getsize(file) for file in files]
frame = dict(zip(files, sizes))
frame
# Out:
# {'./sample_data/california_housing_train.csv': 1706430,
#  './sample_data/mnist_test.csv': 18289443,
#  './sample_data/california_housing_test.csv': 301141,
#  './sample_data/mnist_train_small.csv': 36523880}

# %%
size2file = dict(zip(sizes, files))

# %%
size2file[max(sizes)]
# Out:
# './sample_data/mnist_train_small.csv'

# %%
size2file[min(sizes)]
# Out:
# './sample_data/california_housing_test.csv'

# %%
files
# Out:
# ['./sample_data/california_housing_train.csv',
#  './sample_data/mnist_test.csv',
#  './sample_data/california_housing_test.csv',
#  './sample_data/mnist_train_small.csv']

# %%
sizes
# Out:
# [1706430, 18289443, 301141, 36523880]

# %%
files.sort(key=lambda file: frame[file])
files
# Out:
# ['./sample_data/california_housing_test.csv',
#  './sample_data/california_housing_train.csv',
#  './sample_data/mnist_test.csv',
#  './sample_data/mnist_train_small.csv']
